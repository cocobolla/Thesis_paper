# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
file_path = r'C:\Users\USER\Desktop\paper\KSE_Sector.csv'
df = pd.read_csv(file_path)#, encoding='cp949', thousands=',')
df
# Out:
#          Unnamed: 0 Last Refresh: 2020-05-12 22:28:22         Unnamed: 2  \
# 0    Calendar Basis                               NaN                NaN
# 1         Portfolio                                              Default
# 2              Item
# 3         Frequency                                일간                KRW
# 4   Non-Trading Day                         Exclusive                Asc
# 5   Include Weekend                               ALL
# 6              Term                          20200512  Current(20200512)
# 7            Symbol                           A005930            A005930
# 8       Symbol Name                              삼성전자               삼성전자
# 9              Kind                               COM                COM
# 10             Item                        CP10001310         CP10001340
# 11        Item Name                          거래소 업종구분  한국표준산업분류10차(세세분류)
# 12        Frequency                               NaN                NaN
# ...

# %%
code_idx = 7
type_idx = 11
item_idx = 13
col_types = ['한국표준산업분류10차(세세분류)',
             '한국표준산업분류10차(세분류)',
             '한국표준산업분류10차(소분류)',
             '한국표준산업분류10차(중분류)',
             '한국표준산업분류10차(대분류)']

# %%
col_types[4][12:-1]
# Out:
# '대분류'

# %%
temp_df = df.loc[[code_idx, item_idx], df.loc[type_idx, :] == col_types[0]]
temp_df
# Out:
#         Unnamed: 2                  Unnamed: 8  Unnamed: 14  \
# 7          A005930                     A000660      A207940
# 13  통신 및 방송 장비 제조업  다이오드, 트랜지스터 및 유사 반도체소자 제조업  생물학적 제제 제조업
#
#               Unnamed: 20  Unnamed: 26        Unnamed: 32         Unnamed: 38  \
# 7                 A035420      A068270            A051910             A051900
# 13  포털 및 기타 인터넷 정보매개 서비스업  생물학적 제제 제조업  석유화학계 기초 화학물질 제조업  치약, 비누 및 기타 세제 제조업
#
#              Unnamed: 44 Unnamed: 50 Unnamed: 56  ...    Unnamed: 4604  \
# 7                A005380     A006400     A028260  ...          A012600
# 13  승용차 및 기타 여객용 자동차 제조업     축전지 제조업   기타 전문 도매업  ...  사무용 기계 및 장비 제조업
#
#       Unnamed: 4610 Unnamed: 4616 Unnamed: 4622      Unnamed: 4628  \
# 7           A015260       A000950       A002420            A010580
# 13  인쇄회로기판용 적층판 제조업         면 방적업       영화관 운영업  자동차 엔진용 신품 부품 제조업
#
#     Unnamed: 4634      Unnamed: 4640  Unnamed: 4646           Unnamed: 4652  \
# ...

# %%
p
# Out:
# Empty DataFrame
# Columns: [A005930, A000660, A207940, A035420, A068270, A051910, A051900, A005380, A006400, A028260, A035720, A017670, A012330, A036570, A005490, A055550, A015760, A018260, A105560, A034730, A000270, A033780, A003550, A090430, A032830, A096770, A066570, A000810, A009150, A251270, A086790, A010950, A010130, A011170, A030200, A032640, A316140, A009540, A180640, A035250, A018880, A271560, A021240, A002790, A024110, A097950, A267250, A004990, A034220, A086280, A000720, A006800, A078930, A000100, A029780, A012750, A005830, A000120, A011070, A128940, A008770, A003670, A139480, A012510, A007070, A000210, A004020, A071050, A161390, A010140, A005940, A282330, A003410, A023530, A016360, A036460, A000080, A241560, A009830, A004170, A047810, A001450, A001040, A028050, A011780, A081660, A030000, A008560, A008930, A006360, A007310, A011790, A020150, A042660, A004370, A009240, A003490, A026960, A028670, A006280, ...]
# Index: []
#
# [0 rows x 777 columns]

# %%
sector_df = pd.DataFrame()
for col in col_types:
    temp_df = df.loc[[code_idx, item_idx], df.loc[type_idx, :] == col]
    col_name = col[12:-1]
    sector_series = pd.Series()
    # sector_series.name = 
    for c in temp_df.columns:
        code = temp_df.loc[code_idx, c]
        item = temp_df.loc[item_idx, c]
        sector_series[code] = item
    sector_df[col_name] = sector_series
sector_df
# Out:
#                                세세분류                         세분류  \
# A005930              통신 및 방송 장비 제조업              통신 및 방송 장비 제조업
# A000660  다이오드, 트랜지스터 및 유사 반도체소자 제조업  다이오드, 트랜지스터 및 유사 반도체소자 제조업
# A207940                 생물학적 제제 제조업       기초 의약물질 및 생물학적 제제 제조업
# A035420       포털 및 기타 인터넷 정보매개 서비스업       포털 및 기타 인터넷 정보매개 서비스업
# A068270                 생물학적 제제 제조업       기초 의약물질 및 생물학적 제제 제조업
# ...                             ...                         ...
# A019490               영상 및 음향기기 제조업               영상 및 음향기기 제조업
# A005030           자동차 엔진용 신품 부품 제조업           자동차 엔진용 신품 부품 제조업
# A025890               특수 목적용 기계 제조업               특수 목적용 기계 제조업
# A109070      골판지, 종이 상자 및 종이 용기 제조업      골판지, 종이 상자 및 종이 용기 제조업
# A008500                    편조원단 제조업                    편조원단 제조업
#
#                                       소분류                           중분류  \
# A005930                    통신 및 방송 장비 제조업  전자부품, 컴퓨터, 영상, 음향 및 통신장비 제조업
# ...

# %%
sector_df.T.to_pickle("./kse_sector.pkl")
